# %%
import geopandas as gpd

# %%
in_shp=r"C:\Users\DELL\OneDrive\Desktop\Interpolation\shpfiles\nepal_district\district.shp"

# %%
gdf=gpd.read_file(in_shp)

# %%
gdf
# Out:
#     OBJECTID      DISTRICT        Province  SCode  DCode  SDD   SUM_length  \
# 0          1        ACHHAM  Sudur Pashchim      7     69  769  1702.678726
# 1          2  ARGHAKHANCHI               5      5     51  551  1239.074609
# 2          3       BAGLUNG         Gandaki      4     45  445  1835.741748
# 3          4       BAITADI  Sudur Pashchim      7     74  774  1496.314027
# 4          5       BAJHANG  Sudur Pashchim      7     68  768  3464.299347
# ..       ...           ...             ...    ...    ...  ...          ...
# 72        73       SYANGJA         Gandaki      4     39  439  1037.477867
# 73        74        TANAHU         Gandaki      4     38  438  1571.842407
# 74        75     TAPLEJUNG               1      1      1  101  3643.850847
# 75        76     TERHATHUM               1      1      8  108   672.401219
# 76        77      UDAYAPUR               1      1     14  114  2300.334929
#
#        SUM_area  Shape_Leng  Shape_Area     DistLabel  \
# 0   1702.678726    2.669525    0.157592        Achham
# 1   1239.074609    2.379111    0.113578  Arghakhanchi
# 2   1835.741748    2.885574    0.168958       Baglung
# 3   1496.314027    2.499107    0.138875       Baitadi
# 4   3464.299347    3.156896    0.322441       Bajhang
# ..          ...         ...         ...           ...
# 72  1037.477867    2.306489    0.095215       Syangja
# 73  1571.842407    2.753587    0.144169        Tanahu
# 74  3643.850847    2.879196    0.331930     Taplejung
# 75   672.401219    1.184580    0.061048     Terhathum
# 76  2300.334929    3.715657    0.208663      Udayapur
#
#                           Name_Nep  \
# 0                     à¤
# à¤à¤¾à¤®
# 1   à¤
# à¤°à¥à¤à¤¾à¤à¤¾à¤à¤à¥
# 2               à¤¬à¤¾à¤à¤²à¥à¤
# 3                  à¤¬à¥à¤¤à¤¡à¥
# 4                     à¤¬à¤à¤¾à¤
# ..                             ...
# 72           à¤¸à¥à¤¯à¤¾à¤à¤à¤¾
# 73                 à¤¤à¤¨à¤¹à¥à¤
# 74     à¤¤à¤¾à¤ªà¥à¤²à¥à¤à¥à¤
# 75        à¤¤à¥à¤¹à¥à¤°à¤¥à¥à¤®
# 76              à¤à¤¦à¤¯à¤ªà¥à¤°
#
#                                              geometry
# 0   POLYGON ((81.46795 29.27188, 81.46795 29.27188...
# 1   POLYGON ((83.05092 28.11160, 83.05104 28.11159...
# 2   POLYGON ((83.10729 28.63221, 83.10708 28.63187...
# 3   POLYGON ((80.79590 29.68829, 80.79590 29.68829...
# 4   POLYGON ((81.09080 30.05419, 81.09085 30.05420...
# ..                                                ...
# 72  POLYGON ((83.80918 28.21999, 83.80926 28.21993...
# 73  POLYGON ((84.47750 28.05817, 84.47747 28.05794...
# 74  POLYGON ((88.06785 27.43833, 88.06778 27.43830...
# 75  POLYGON ((87.67973 27.27106, 87.68029 27.26858...
# 76  POLYGON ((86.43335 27.14908, 86.43348 27.14905...
#
# [77 rows x 13 columns]

# %%
gdf.head(10)
# Out:
#    OBJECTID      DISTRICT        Province  SCode  DCode  SDD   SUM_length  \
# 0         1        ACHHAM  Sudur Pashchim      7     69  769  1702.678726
# 1         2  ARGHAKHANCHI               5      5     51  551  1239.074609
# 2         3       BAGLUNG         Gandaki      4     45  445  1835.741748
# 3         4       BAITADI  Sudur Pashchim      7     74  774  1496.314027
# 4         5       BAJHANG  Sudur Pashchim      7     68  768  3464.299347
# 5         6        BAJURA  Sudur Pashchim      7     67  767  2300.349794
# 6         7         BANKE               5      5     57  557  1882.278883
# 7         8          BARA               2      2     33  233  1272.612081
# 8         9       BARDIYA               5      5     58  558  2003.526482
# 9        10     BHAKTAPUR         Bagmati      3     26  326   123.106723
#
#       SUM_area  Shape_Leng  Shape_Area     DistLabel  \
# 0  1702.678726    2.669525    0.157592        Achham
# 1  1239.074609    2.379111    0.113578  Arghakhanchi
# 2  1835.741748    2.885574    0.168958       Baglung
# 3  1496.314027    2.499107    0.138875       Baitadi
# 4  3464.299347    3.156896    0.322441       Bajhang
# 5  2300.349794    2.977666    0.213900        Bajura
# 6  1882.278883    2.284589    0.172657         Banke
# 7  1272.612081    2.321087    0.115816          Bara
# 8  2003.526482    2.620289    0.184193       Bardiya
# 9   123.078504    0.575090    0.011258     Bhaktapur
#
#                          Name_Nep  \
# 0                    à¤
# à¤à¤¾à¤®
# 1  à¤
# à¤°à¥à¤à¤¾à¤à¤¾à¤à¤à¥
# 2              à¤¬à¤¾à¤à¤²à¥à¤
# 3                 à¤¬à¥à¤¤à¤¡à¥
# 4                    à¤¬à¤à¤¾à¤
# 5              à¤¬à¤¾à¤à¥à¤°à¤¾
# 6                 à¤¬à¤¾à¤à¤à¥
# 7                    à¤¬à¤¾à¤°à¤¾
# 8           à¤¬à¤°à¥à¤¦à¤¿à¤¯à¤¾
# 9           à¤­à¤à¥à¤¤à¤ªà¥à¤°
#
#                                             geometry
# 0  POLYGON ((81.46795 29.27188, 81.46795 29.27188...
# 1  POLYGON ((83.05092 28.11160, 83.05104 28.11159...
# 2  POLYGON ((83.10729 28.63221, 83.10708 28.63187...
# 3  POLYGON ((80.79590 29.68829, 80.79590 29.68829...
# 4  POLYGON ((81.09080 30.05419, 81.09085 30.05420...
# 5  POLYGON ((81.77366 29.60580, 81.77399 29.60547...
# 6  POLYGON ((81.74497 28.31326, 81.74503 28.31326...
# 7  POLYGON ((85.26922 27.22806, 85.26925 27.22803...
# 8  POLYGON ((81.76659 28.37015, 81.76654 28.37007...
# 9  POLYGON ((85.52502 27.72562, 85.52502 27.72544...

# %%
len(gdf)
# Out:
# 77

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.geom_type
# Out:
# 0     Polygon
# 1     Polygon
# 2     Polygon
# 3     Polygon
# 4     Polygon
#        ...
# 72    Polygon
# 73    Polygon
# 74    Polygon
# 75    Polygon
# 76    Polygon
# Length: 77, dtype: object

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.plot("DISTRICT")
# Out:
# <Axes: >

# %%
gdf.plot("Province")
# Out:
# <Axes: >

# %%
gdf.plot("Province",cmap='hsv',legend=True)
# Out:
# <Axes: >

# %%
gdf.plot("SUM_area",cmap='hsv',legend=True)
# Out:
# <Axes: >

# %%
gdf.plot("SUM_area",cmap='ocean',legend=True,vmin=1000,vmax=6000)
# Out:
# <Axes: >

# %%
gdf.plot("SUM_area",cmap='ocean',legend=True,vmin=1000,vmax=6000,edgecolor='gray')
# Out:
# <Axes: >

# %%
provinces=gdf['Province'].unique()

# %%
gdf=gdf.replace({'5':'Lumbini','2':'Madesh','1':'Koshi'})

# %%
provinces=gdf['Province'].unique()

# %%
provinces
# Out:
# array(['Sudur Pashchim', 'Lumbini', 'Gandaki', 'Madesh', 'Bagmati',
#        'Koshi', 'Karnali'], dtype=object)
